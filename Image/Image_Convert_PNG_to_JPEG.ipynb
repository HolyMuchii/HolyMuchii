# %% [markdown]
# <a href="https://colab.research.google.com/github/HolyMuchii/HolyMuchii/blob/main/Image/Image_Convert_PNG_to_JPEG.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Converter Imagens de PNG para JPEG
# ## Importar e Salvar
# Pacotes Utilizados: imageio, cv2, PIL
#
# # Pacote Recomendado: PIL

# %% [markdown]
# Dados da Imagem Utilizada:
# - Resolução Espacial: 755 x 527 pixels
# - Resolução de Profundidade: 32 bits (4x8 bits)

# %%
import imageio as io
import numpy as np
import matplotlib.pyplot as plt
import cv2
from PIL import Image

# %%
# !git clone https://github.com/HolyMuchii/AqusicaoDados.git
# Out:
# Cloning into 'AqusicaoDados'...
# remote: Enumerating objects: 17, done.
# remote: Counting objects: 100% (17/17), done.
# remote: Compressing objects: 100% (13/13), done.
# remote: Total 17 (delta 2), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (17/17), done.

# %%
pinIo = io.imread('AqusicaoDados/Image/pinguin.PNG')
pinCV = cv2.imread('AqusicaoDados/Image/pinguin.PNG')
pinPIL = Image.open('AqusicaoDados/Image/pinguin.PNG').convert('RGB')


fig,ax = plt.subplots(1,3,figsize=(15,15))
ax[0].imshow(pinIo)
ax[0].set_title('imageo.PNG')

ax[1].imshow(pinCV)
ax[1].set_title('cv2.PNG')

ax[2].imshow(pinPIL)
ax[2].set_title('PIL.PNG - Não tem shape')
plt.show()

# %%
print('imageio Type&shape :.',type(pinIo),pinIo.shape,'\ncv2 Type&shape :.',type(pinCV),pinCV.shape,'\nPIL Type&shape :.',type(pinPIL))
# Out:
# imageio Type&shape :. <class 'imageio.core.util.Array'> (527, 755, 4)
# cv2 Type&shape :. <class 'numpy.ndarray'> (527, 755, 3)
# PIL Type&shape :. <class 'PIL.Image.Image'>

# %%
cv2.imwrite('pinguinCV.JPG', pin)
# io.imwrite('pinguinIo.JPG', pin) # OSError: JPEG does not support alpha channel.
pi.save('pinguinPIL.JPG')

# %% [markdown]
# - Imageio: Conseguiu ler 4 bandas, mas não conseguiu converter o PNG para o JPEG
# - cv2: Conseguiu ler 3 bandas, com distorções de cores visíveis
# - PIL: Não apresentou distorção de cores visível e conseguiu salvar os dados

# %% [markdown]
# ## Todas as Imagens Salvas serão lidas em Array
#
# #### Imageio não conseguiu converter as 4 bandas de PNG para as 3 bandas do JPEG

# %%
piCV = io.imread('pinguinCV.JPG')
piPIL = io.imread('pinguinPIL.JPG')

fig,ax = plt.subplots(1,3,figsize=(15,15))
ax[0].imshow(pinIo)
ax[0].set_title('imageo.PNG')

ax[1].imshow(piCV)
ax[1].set_title('cv2.JPEG')

ax[2].imshow(piPIL)
ax[2].set_title('PIL.JPEG')
plt.show()

# %%
print('PIL Type&shape :.',type(piPIL),piPIL.shape,'\ncv2 Type&shape :.',type(piCV),piCV.shape)
# Out:
# PIL Type&shape :. <class 'imageio.core.util.Array'> (527, 755, 3)
# cv2 Type&shape :. <class 'imageio.core.util.Array'> (527, 755, 3)
